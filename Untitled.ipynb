# %%
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import numpy as np
#
# ModuleNotFoundError: No module named 'numpy'

# %%
pip install numpy
# Out:
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/61.0 kB ? eta -:--:--
#      ------------------------------- ------ 51.2/61.0 kB 660.6 kB/s eta 0:00:01
#      -------------------------------------- 61.0/61.0 kB 546.2 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.8 MB 1.4 MB/s eta 0:00:12
#    ---------------------------------------- 0.1/15.8 MB 1.1 MB/s eta 0:00:15
#    ---------------------------------------- 0.2/15.8 MB 1.2 MB/s eta 0:00:14
#     --------------------------------------- 0.2/15.8 MB 1.4 MB/s eta 0:00:12
#     --------------------------------------- 0.3/15.8 MB 1.2 MB/s eta 0:00:13
#     --------------------------------------- 0.4/15.8 MB 1.4 MB/s eta 0:00:11
#    - -------------------------------------- 0.5/15.8 MB 1.6 MB/s eta 0:00:10
# ...

# %%
import numpy as np

# %%
random_int = np.random.randint(50,size=10)
random_int
# Out:
# array([ 1, 13, 40, 40, 40, 42,  2, 45, 10,  4])

# %%
random_int.mean()
random_int
# Out:
# array([ 1, 13, 40, 40, 40, 42,  2, 45, 10,  4])

# %%
np.mean(random_int)
# Out:
# 23.7

# %%
arr=np.random.randint(50,size=(2,3))
arr2==np.random.randint(50,size=(2,3))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 arr=np.random.randint(50,size=(2,3))
# ----> 2 arr2==np.random.randint(50,size=(2,3))
#
# NameError: name 'arr2' is not defined

# %%
arr=np.random.randint(50,size=(2,3))
arr2=np.random.randint(50,size=(2,3))
arr
arr2
# Out:
# array([[45, 21, 30],
#        [25, 26,  4]])

# %%
arr
# Out:
# array([[20,  4, 43],
#        [34, 36, 45]])

# %%
arr2
# Out:
# array([[45, 21, 30],
#        [25, 26,  4]])

# %%
arr3=np.add(arr,arr2)

# %%
arr3
# Out:
# array([[65, 25, 73],
#        [59, 62, 49]])

# %%
np.mean(arr3)
# Out:
# 55.5

# %%
arrr=np.random.randint(1,100,size=20)

# %%
arrr
# Out:
# array([51, 33, 83,  3, 73, 14, 13, 27, 91, 14, 44, 13, 43, 59, 78, 34, 93,
#        50, 92, 26])

# %%
condition = arrr > 50
filtered_arr = arrr[condition]
filtered_arr
# Out:
# array([51, 83, 73, 91, 59, 78, 93, 92])

# %%
arr44 = np.random.randint(1,10,size=10)                                          
 random.shuffle(arr44)                                             
 arr44
# Out:
#   Cell In[17], line 2
#     random.shuffle(arr44)
#     ^
# IndentationError: unexpected indent

# %%
arr44 = np.random.randint(1,10,size=10)                                          
np.random.shuffle(arr44)                                             
arr44
# Out:
#   Cell In[18], line 2
#     np.random.shuffle(arr44)
#     ^
# IndentationError: unexpected indent

# %%
arr44 = np.random.randint(1,10,size=10)                                          
np.random.shuffle(arr44)                                             
arr44
# Out:
# array([1, 1, 4, 6, 2, 2, 6, 8, 5, 2])

# %%
x=np.random.randint(10)
arr44[x]
# Out:
# 6
